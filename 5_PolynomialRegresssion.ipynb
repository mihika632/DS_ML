# %% [markdown]
# # LINEAR REGRESSION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Salary_Data.csv')
x = df[['YearsExperience']]
y = df['Salary']

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x,y)
print('Accuracy : ', reg.score(x,y))
# Out:
# Accuracy :  0.9569566641435086

# %% [markdown]
# # POLYNOMIAL TRANSFORM

# %%
#import the class
from sklearn.preprocessing import PolynomialFeatures

# %%
# create obj
poly = PolynomialFeatures(degree=2)

# %%
#apply polynomial transform
x_poly = poly.fit_transform(x)

# %%
x_poly
# Out:
# array([[1.00000000e+00, 1.10000000e+00, 1.21000000e+00, 1.33100000e+00,
#         1.46410000e+00, 1.61051000e+00, 1.77156100e+00, 1.94871710e+00,
#         2.14358881e+00, 2.35794769e+00, 2.59374246e+00, 2.85311671e+00,
#         3.13842838e+00, 3.45227121e+00, 3.79749834e+00, 4.17724817e+00,
#         4.59497299e+00, 5.05447028e+00, 5.55991731e+00, 6.11590904e+00],
#        [1.00000000e+00, 1.30000000e+00, 1.69000000e+00, 2.19700000e+00,
#         2.85610000e+00, 3.71293000e+00, 4.82680900e+00, 6.27485170e+00,
#         8.15730721e+00, 1.06044994e+01, 1.37858492e+01, 1.79216039e+01,
#         2.32980851e+01, 3.02875107e+01, 3.93737639e+01, 5.11858930e+01,
#         6.65416609e+01, 8.65041592e+01, 1.12455407e+02, 1.46192029e+02],
#        [1.00000000e+00, 1.50000000e+00, 2.25000000e+00, 3.37500000e+00,
#         5.06250000e+00, 7.59375000e+00, 1.13906250e+01, 1.70859375e+01,
#         2.56289062e+01, 3.84433594e+01, 5.76650391e+01, 8.64975586e+01,
# ...

# %%
reg = LinearRegression()
reg.fit(x_poly,y)
print('Accuracy : ', reg.score(x_poly,y))
# Out:
# Accuracy :  0.9585869043656873

# %%
acc= []
for i in range(2,21):
    poly = PolynomialFeatures(degree=i)
    x_poly = poly.fit_transform(x)
    reg = LinearRegression()
    reg.fit(x_poly,y)
    acc.append(reg.score(x_poly,y))

# %%
plt.grid()
plt.figure(figsize=(4,4))
plt.plot(range(2,21), acc, color = 'g')

# %%
acc
# Out:
# [0.956975168321065,
#  0.9635969766249464,
#  0.9636560599375091,
#  0.9665546834956733,
#  0.9673693577169906,
#  0.9722578921026915,
#  0.9728154307146053,
#  0.973296909756007,
#  0.9809837385230955,
#  0.9821835719441067,
#  0.9830443660286551,
#  0.9829904174696475,
#  0.981969491450428,
#  0.9804882257606695,
#  0.9792395345026208,
#  0.9800339561284577,
#  0.9655365740336253,
#  0.9585869043656873,
#  0.9539469721099573]

# %%
poly = PolynomialFeatures(degree=i)
x_poly = poly.fit_transform(x)
reg = LinearRegression()
reg.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_poly)
plt.scatter(x,y)
plt.grid()
plt.plot(x,y_pred, color = 'r')

# %%
reg.predict(poly.transform([[15]]))
# Out:
# array([1.42986013e+12])

# %% [markdown]
# # overfitting and underfitting
# <!-- overfitting -->  over-fit/memorizing(MR. mug it all)
# <!-- underfitting -->  biased learning(uninterested one
# <!-- best fit --> traing and testing data should have min difference

# %% [markdown]
# # LOGISTICE RESGRESSION
# <!-- ln(p/1-p) = b0 + b1*x --> signoid fncction

# %%
# when o/p variable is binary 
# is a classification algo
#signoid formula ==> p = 1/(1+e^-y)
