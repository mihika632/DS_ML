# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('grapes_new.csv')

# %%
df
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
# ...

# %%
df.shape
# Out:
# (194, 21)

# %%
df.columns
# Out:
# Index(['COLOR_INTENSITY', 'SHAPE', 'RIPENESS_PER', 'ALCOHOL_PER',
#        'MALIC_ACID_PER', 'ASH', 'ALCALINITY_OF_ASH', 'MAGNESIUM_MEASURE',
#        'TOTAL_PHENOLS', 'FLAVANOIDS', 'PROANTHOCYANINS', 'HUE', 'PROLINE',
#        'TEMPERATURE', 'AVG_HUMIDITY', 'FERT_NITRO_PER', 'WATER_O2_PER',
#        'WATER_PH', 'FER_P2O5_PER', 'SOIL_TYPE', 'CLASS'],
#       dtype='object')

# %%
# # steps
# 1. data import
# 2. data cleaning - missing values
# 3. exploratory data analysis
# 4. outlier detection and removal
# 5. data balancing / resampling(optional)
# 6 feature scaling or dimentionality reduction
# 7. feature scaling
# 8 cross validation
# 9 suitable algo
# 11. model building
# 11. prediction, performance monitoring
# 12 deployment(optional)

# %% [markdown]
# #  data cleaning

# %%
df.count()
# Out:
# COLOR_INTENSITY      194
# SHAPE                194
# RIPENESS_PER         192
# ALCOHOL_PER          191
# MALIC_ACID_PER       194
# ASH                  194
# ALCALINITY_OF_ASH    188
# MAGNESIUM_MEASURE    194
# TOTAL_PHENOLS        194
# FLAVANOIDS           194
# PROANTHOCYANINS      194
# HUE                  192
# PROLINE              194
# TEMPERATURE          194
# AVG_HUMIDITY         194
# FERT_NITRO_PER       194
# WATER_O2_PER         190
# WATER_PH             194
# FER_P2O5_PER         194
# SOIL_TYPE            194
# CLASS                194
# dtype: int64

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         2
# ALCOHOL_PER          3
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    6
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  2
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         4
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %%
# can use bfill or padding method to recover at single step

# %%
df.fillna(method='pad', inplace = True)

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         0
# ALCOHOL_PER          0
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    0
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  0
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         0
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %%
# separate input and output data

# %%
x = df.drop('CLASS', axis = 1)
y = df['CLASS']

# %%
sns.countplot(x = df['SHAPE'])
# Out:
# <Axes: xlabel='SHAPE', ylabel='count'>

# %%
sns.countplot(x = df['SOIL_TYPE'])
# Out:
# <Axes: xlabel='SOIL_TYPE', ylabel='count'>

# %% [markdown]
# # LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
x['SHAPE'] = le.fit_transform(x['SHAPE'])
x['SOIL_TYPE'] = le.fit_transform(x['SOIL_TYPE'])

# %%
x.dtypes
# Out:
# COLOR_INTENSITY      float64
# SHAPE                  int32
# RIPENESS_PER         float64
# ALCOHOL_PER          float64
# MALIC_ACID_PER       float64
# ASH                  float64
# ALCALINITY_OF_ASH    float64
# MAGNESIUM_MEASURE      int64
# TOTAL_PHENOLS        float64
# FLAVANOIDS           float64
# PROANTHOCYANINS      float64
# HUE                  float64
# PROLINE                int64
# TEMPERATURE          float64
# AVG_HUMIDITY         float64
# FERT_NITRO_PER       float64
# WATER_O2_PER         float64
# WATER_PH             float64
# FER_P2O5_PER         float64
# SOIL_TYPE              int32
# dtype: object

# %%
# label is used when you have two classes
# for multiple classes --> one hot encoding

# %%
x.head()
# Out:
#    COLOR_INTENSITY  SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER   ASH  \
# 0           120.53      0         16.73        14.23            1.71  2.43
# 1           112.57      0         20.30        13.20            1.78  2.14
# 2           120.78      0         20.81        13.16            2.36  2.67
# 3           134.17      0         19.47        14.37            1.95  2.50
# 4           112.19      1         17.57        13.24            2.59  2.87
#
#    ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# 0               15.6                127           2.80        3.06
# 1               11.2                100           2.65        2.76
# 2               18.6                101           2.80        3.24
# 3               16.8                113           3.85        3.49
# 4               21.0                118           2.80        2.69
#
#    PROANTHOCYANINS   HUE  PROLINE  TEMPERATURE  AVG_HUMIDITY  FERT_NITRO_PER  \
# ...

# %%
le.classes_   #to get 0 & 1's original label(meaning)
# Out:
# array(['alluvial', 'archean'], dtype=object)

# %%
#### explore data analysis

# %%
#visualization method

# %%
sns.countplot(x =y)
# Out:
# <Axes: xlabel='CLASS', ylabel='count'>

# %%
y.value_counts()
# Out:
# CLASS
# Medium    76
# High      64
# Low       54
# Name: count, dtype: int64

# %%
sns.jointplot(x = 'COLOR_INTENSITY', y= 'TEMPERATURE', data = df, hue = 'CLASS')

# %%
# 5 - k5 k columns banao

one = df.iloc[:, 0:5]
one['CLASS']= y

two = df.iloc[:, 5:10]
two['CLASS']= y
three = df.iloc[:, 10:15]
three['CLASS']= y
four = df.iloc[:, 15:20]
four['CLASS']= y

# %%
# then unkapairplot

# %%
sns.pairplot(one, hue='CLASS')
# Out:
# C:\Users\mihik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(two, hue='CLASS')
# Out:
# C:\Users\mihik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(three, hue='CLASS')
# Out:
# C:\Users\mihik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(four, hue='CLASS')
# Out:
# C:\Users\mihik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # oytlier detection and removal

# %%
from sklearn.ensemble import IsolationForest

# %%
iso = IsolationForest(contamination=0.05, random_state=0)

# %%
clean =iso.fit_predict(x,y)

# %%
x_clean=x[clean == 1]
y_clean=y[clean == 1]

# %%
x_clean.shape, y_clean.shape
# Out:
# ((184, 20), (184,))

# %% [markdown]
# # FEATURE SELECTION

# %%
from sklearn.feature_selection import SelectKBest, chi2i2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 from sklearn.feature_selection import SelectKBest, chi2i2
#
# ImportError: cannot import name 'chi2i2' from 'sklearn.feature_selection' (C:\Users\mihik\anaconda3\Lib\site-packages\sklearn\feature_selection\__init__.py)

# %%
skf = SelectKBest(k = 5, score_func = chi2)

# %%
skf.fit(x_clean,y)

# %%
skf.get_support()

# %%
x_clean = x_clean.iloc[:, skf.get_support()]

# %%
x

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_scaled = scaler.fit_transform(x_clean)

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#                 0           1           2           3           4
# count  194.000000  194.000000  194.000000  194.000000  194.000000
# mean     0.322731    0.353767    0.339633    0.476877    0.543067
# std      0.193692    0.211255    0.225459    0.268760    0.254421
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.168514    0.158755    0.161198    0.282906    0.336249
# 50%      0.296081    0.378692    0.283167    0.457155    0.607291
# 75%      0.419730    0.534810    0.506954    0.681758    0.747309
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# # CROSS VALIDATION

# %%
from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_clean, random_state=0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_clean, random_state=0)
# x_train.shape, x_test.shape/
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_clean, random_state=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
# ...

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_clean, test_size=0.2, random_state=0)

# Verify the shapes of the resulting arrays
print("Shape of x_train:", x_train.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 4
#       1 from sklearn.model_selection import train_test_split
#       3 # Split the data into training and testing sets
# ----> 4 x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_clean, test_size=0.2, random_state=0)
#       6 # Verify the shapes of the resulting arrays
#       7 print("Shape of x_train:", x_train.shape)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
# ...

# %% [markdown]
# #  build the model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state=0)

# %%
clf.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 clf.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# # PERFORMANCE ANALYSIS

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay
y_pred = clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 3
#       1 from sklearn.metrics import accuracy_score, classification_report
#       2 from sklearn.metrics import ConfusionMatrixDisplay
# ----> 3 y_pred = clf.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 accuracy_score(y_test, y_pred)
#
# NameError: name 'y_test' is not defined

# %%
# new = [[]]
# clf.predict(scaler.transform(new))[0]
