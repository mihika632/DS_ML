# %% [markdown]
# # POLYNOMIAL REGRESSION

# %%
#  y = b0 + b1x^1 + b2x^2 .......+ bnX^n
# i/p ->( polynomial transform -> linearregression ) -> predictions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
x = np.arange(0,10,0.25)

# %%
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25,
#        5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ,
#        8.25, 8.5 , 8.75, 9.  , 9.25, 9.5 , 9.75])

# %%
x.shape
# Out:
# (40,)

# %% [markdown]
# # LINEAR FUNCTION

# %%
y = x*23.06 + 45.27

# %%
y
# Out:
# array([ 45.27 ,  51.035,  56.8  ,  62.565,  68.33 ,  74.095,  79.86 ,
#         85.625,  91.39 ,  97.155, 102.92 , 108.685, 114.45 , 120.215,
#        125.98 , 131.745, 137.51 , 143.275, 149.04 , 154.805, 160.57 ,
#        166.335, 172.1  , 177.865, 183.63 , 189.395, 195.16 , 200.925,
#        206.69 , 212.455, 218.22 , 223.985, 229.75 , 235.515, 241.28 ,
#        247.045, 252.81 , 258.575, 264.34 , 270.105])

# %%
plt.plot(x,y)

# %% [markdown]
# # POLYNOMIAL FUNCTION

# %%
y = x**4 + 56.89

# %%
y
# Out:
# array([  56.89      ,   56.89390625,   56.9525    ,   57.20640625,
#          57.89      ,   59.33140625,   61.9525    ,   66.26890625,
#          72.89      ,   82.51890625,   95.9525    ,  114.08140625,
#         137.89      ,  168.45640625,  206.9525    ,  254.64390625,
#         312.89      ,  383.14390625,  466.9525    ,  565.95640625,
#         681.89      ,  816.58140625,  971.9525    , 1150.01890625,
#        1352.89      , 1582.76890625, 1841.9525    , 2132.83140625,
#        2457.89      , 2819.70640625, 3220.9525    , 3664.39390625,
#        4152.89      , 4689.39390625, 5276.9525    , 5918.70640625,
#        6617.89      , 7377.83140625, 8201.9525    , 9093.76890625])

# %%
plt.figure(figsize= (4,4))
plt.plot(x,y)

# %%
plt.plot(x, np.log(x))

# %%
plt.plot(x, np.tan(x))
