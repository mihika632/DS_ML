# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#when data is in continuous form --> use histogram

sns.histplot(tips['total_bill'])
plt.title('HISTOGRAM OF TOTAL BILL')
plt.xlabel('total bill')
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
#when data is in continuous form --> use histogram
#kde --> for frequency distribution curve


sns.histplot(tips['total_bill'], kde = 'True')
plt.title('HISTOGRAM OF TOTAL BILL')
plt.xlabel('total bill')
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips)
plt.title(' total bill by day');

# %%
sns.pairplot(tips);

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips)
plt.title(' total bill by day');

# %%
# quantitative and nominal data
#qualitative <==> catogorical data
# discrete --> no fractions involved
# continuous data --> fractions involved


# nominal data --> no order present (eq:color of smartphone)
# ordinal data --> natural ordering(ep : S,M,L,XL,XXL,XS,XXS)
# labelling/label encoding -> convert categorical data to numbers
# data encoding --> qualitative data is imp
# quantitative data type -> quantifying things (types --> decrete and continuous)


# types of variables --> independent and dependent variables
# independent --> cause (or reason) of dependent variable

# %% [markdown]
# # FEATURE SCALING TECHNIQUES

# %%
# normalization --> min-max scaler
#               --> values are shifted and rescaled s they end up b/w 0&1
#               --> X' =( X - Xmin)/(Xmax - Xmin)

#standardization --> z = (xi-u)/sigma


#normalized(range--> 0 to 1, 1st quadrant ) and standardized data(mean = 0, std deviation = 1, i.e centralized rehta h)
